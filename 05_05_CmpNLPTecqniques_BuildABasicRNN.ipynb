# %% [markdown]
# # Compare NLP Techniques: Build A Basic RNN

# %% [markdown]
# ### Read In Cleaned Text

# %%
# Load the cleaned training and test sets
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import pandas as pd

X_train = pd.read_csv('data/X_train.csv')
X_test = pd.read_csv('data/X_test.csv')
y_train = pd.read_csv('data/y_train.csv')
y_test = pd.read_csv('data/y_test.csv')
# Out:
# 2024-03-03 05:59:13.208624: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-03 05:59:13.266228: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-03 05:59:13.266273: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-03 05:59:13.270695: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-03 05:59:13.280098: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-03 05:59:13.281436: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-03 05:59:15.162439: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### Prep Data

# %%
# Train the tokenizer and use that tokenizer to convert the sentences to sequences of numbers
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train['clean_text'])
X_train_seq = tokenizer.texts_to_sequences(X_train['clean_text'])
X_test_seq = tokenizer.texts_to_sequences(X_test['clean_text'])

# %%
# Pad the sequences so each sequence is the same length
X_train_seq_padded = pad_sequences(X_train_seq, 50)
X_test_seq_padded = pad_sequences(X_test_seq, 50)

# %% [markdown]
# ### Build And Evaluate RNN

# %%
# Import the tools needed and use our previously defined functions to calculate precision and recall
import keras.backend as K
from keras.layers import Dense, Embedding, LSTM
from keras.models import Sequential

def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

# %%
# Construct our basic RNN model framework
model = Sequential()

model.add(Embedding(len(tokenizer.index_word)+1, 32))
model.add(LSTM(32, dropout=0, recurrent_dropout=0))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 32)          265472
#
#  lstm (LSTM)                 (None, 32)                8320
#
#  dense (Dense)               (None, 32)                1056
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 274881 (1.05 MB)
# Trainable params: 274881 (1.05 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy', precision_m, recall_m])

# %%
# Fit the RNN
history = model.fit(X_train_seq_padded, y_train['label'], 
                    batch_size=32, epochs=10,
                    validation_data=(X_test_seq_padded, y_test))
# Out:
# Epoch 1/10
# 140/140 [==============================] - 5s 18ms/step - loss: 0.2540 - accuracy: 0.9174 - precision_m: 0.4874 - recall_m: 0.3841 - val_loss: 0.0967 - val_accuracy: 0.9749 - val_precision_m: 0.9869 - val_recall_m: 0.8612
# Epoch 2/10
# 140/140 [==============================] - 2s 15ms/step - loss: 0.0327 - accuracy: 0.9919 - precision_m: 0.9843 - recall_m: 0.9359 - val_loss: 0.0702 - val_accuracy: 0.9821 - val_precision_m: 0.9768 - val_recall_m: 0.9135
# Epoch 3/10
# 140/140 [==============================] - 2s 15ms/step - loss: 0.0093 - accuracy: 0.9975 - precision_m: 0.9909 - recall_m: 0.9810 - val_loss: 0.0873 - val_accuracy: 0.9812 - val_precision_m: 0.9800 - val_recall_m: 0.9042
# Epoch 4/10
# 140/140 [==============================] - 2s 14ms/step - loss: 0.0033 - accuracy: 0.9993 - precision_m: 0.9929 - recall_m: 0.9879 - val_loss: 0.0851 - val_accuracy: 0.9830 - val_precision_m: 0.9624 - val_recall_m: 0.9283
# Epoch 5/10
# 140/140 [==============================] - 2s 16ms/step - loss: 6.4975e-04 - accuracy: 1.0000 - precision_m: 0.9929 - recall_m: 0.9929 - val_loss: 0.1027 - val_accuracy: 0.9803 - val_precision_m: 0.9657 - val_recall_m: 0.9042
# Epoch 6/10
# 140/140 [==============================] - 2s 15ms/step - loss: 4.7922e-04 - accuracy: 0.9998 - precision_m: 0.9857 - recall_m: 0.9839 - val_loss: 0.0958 - val_accuracy: 0.9812 - val_precision_m: 0.9624 - val_recall_m: 0.9131
# Epoch 7/10
# 140/140 [==============================] - 2s 15ms/step - loss: 2.4423e-04 - accuracy: 1.0000 - precision_m: 0.9857 - recall_m: 0.9857 - val_loss: 0.1073 - val_accuracy: 0.9812 - val_precision_m: 0.9624 - val_recall_m: 0.9131
# Epoch 8/10
# 140/140 [==============================] - 2s 15ms/step - loss: 1.1568e-04 - accuracy: 1.0000 - precision_m: 0.9857 - recall_m: 0.9857 - val_loss: 0.1119 - val_accuracy: 0.9803 - val_precision_m: 0.9657 - val_recall_m: 0.9042
# Epoch 9/10
# 140/140 [==============================] - 2s 15ms/step - loss: 7.5311e-05 - accuracy: 1.0000 - precision_m: 0.9857 - recall_m: 0.9857 - val_loss: 0.1160 - val_accuracy: 0.9803 - val_precision_m: 0.9657 - val_recall_m: 0.9042
# Epoch 10/10
# 140/140 [==============================] - 2s 14ms/step - loss: 5.4676e-05 - accuracy: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 0.1175 - val_accuracy: 0.9812 - val_precision_m: 0.9667 - val_recall_m: 0.9099

# %%
# Plot basic evaluation metrics across epochs
import matplotlib.pyplot as plt
# %matplotlib inline

for i in ['accuracy', 'precision_m', 'recall_m']:
    acc = history.history[i]
    val_acc = history.history['val_{}'.format(i)]
    epochs = range(1, len(acc) + 1)

    plt.figure()
    plt.plot(epochs, acc, label='Training Accuracy')
    plt.plot(epochs, val_acc, label='Validation Accuracy')
    plt.title('Results for {}'.format(i))
    plt.legend()
    plt.show()
