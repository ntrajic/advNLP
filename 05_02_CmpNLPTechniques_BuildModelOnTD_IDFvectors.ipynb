# %% [markdown]
# # Compare NLP Techniques: Build Model On TF-IDF Vectors

# %% [markdown]
# ### Read In Cleaned Text

# %%
# Load the cleaned training and test sets
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

X_train = pd.read_csv('data/X_train.csv')
X_test = pd.read_csv('data/X_test.csv')
y_train = pd.read_csv('data/y_train.csv')
y_test = pd.read_csv('data/y_test.csv')

X_train.head()
# Out:
# /tmp/ipykernel_18250/3764338648.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#                                           clean_text
# 0                     ['spare', 'power', 'supplies']
# 1  ['urgent', 'trying', 'contact', 'u', 'todays',...
# 2  ['1st', 'wk', 'free', 'gr8', 'tones', 'str8', ...
# 3                                   ['call', 'meet']
# 4  ['haha', 'really', 'oh', 'deduct', 'lesson', '...

# %% [markdown]
# ### Create TF-IDF Vectors

# %%
# Instantiate and fit a TFIDF vectorizer and then use that trained vectorizer
# to transform the messages in the training and test sets
tfidf_vect = TfidfVectorizer()
tfidf_vect.fit(X_train['clean_text'])
X_train_vect = tfidf_vect.transform(X_train['clean_text'])
X_test_vect = tfidf_vect.transform(X_test['clean_text'])

# %%
# What words did the vectorizer learn?
tfidf_vect.vocabulary_
# Out:
# {'spare': 6728,
#  'power': 5672,
#  'supplies': 7002,
#  'urgent': 7611,
#  'trying': 7465,
#  'contact': 2077,
#  'todays': 7336,
#  'draw': 2567,
#  'shows': 6492,
#  '800': 694,
#  'prize': 5751,
#  'guaranteed': 3416,
#  'call': 1678,
#  '09050001808': 163,
#  'land': 4234,
#  'line': 4360,
#  'claim': 1920,
#  'm95': 4534,
#  'valid12hrs': 7659,
#  '1st': 373,
#  'wk': 7982,
#  'free': 3122,
#  'gr8': 3363,
#  'tones': 7362,
#  'str8': 6896,
#  'txt': 7500,
#  'nokia': 5095,
#  '8007': 697,
#  'classic': 1927,
#  'hit': 3601,
#  'polys': 5624,
#  'nokia150p': 5096,
#  'poly200p': 5618,
#  '16': 344,
#  'meet': 4673,
#  'haha': 3449,
#  'really': 5938,
#  'oh': 5221,
#  'deduct': 2342,
#  'lesson': 4317,
#  'tmr': 7325,
#  'sounds': 6712,
#  'great': 3386,
#  'home': 3638,
#  'login': 4415,
#  'dat': 2280,
#  'time': 7297,
#  'dad': 2248,
#  'fetching': 2954,
#  'probably': 5757,
#  'still': 6868,
#  'going': 3321,
#  'stuff': 6930,
#  'hey': 3578,
#  'guy': 3434,
#  'know': 4184,
#  'breathing': 1564,
#  'neck': 5004,
#  'get': 3262,
#  'bud': 1612,
#  'anyway': 1060,
#  'youd': 8204,
#  'able': 817,
#  'half': 3458,
#  'track': 7410,
#  'usf': 7632,
#  'tonight': 7367,
#  'enjoying': 2733,
#  'semester': 6358,
#  'take': 7074,
#  'care': 1735,
#  'brother': 1590,
#  'youdoing': 8205,
#  'later': 4260,
#  'sar': 6251,
#  'xxx': 8141,
#  'said': 6226,
#  'mind': 4756,
#  'go': 3305,
#  'bedroom': 1342,
#  'minute': 4772,
#  'ok': 5225,
#  'sed': 6334,
#  'sexy': 6400,
#  'mood': 4859,
#  'came': 1708,
#  'minuts': 4774,
#  'latr': 4264,
#  'wid': 7932,
#  'caken': 1671,
#  'wife': 7935,
#  'shuhui': 6497,
#  'say': 6275,
#  'change': 1813,
#  'suntec': 6995,
#  'steamboat': 6851,
#  'noe': 5087,
#  'try': 7463,
#  'week': 7858,
#  'end': 2716,
#  'course': 2140,
#  'coimbatore': 1978,
#  'message': 4715,
#  'welcome': 7875,
#  'new': 5035,
#  'improved': 3818,
#  'sex': 6398,
#  'dogging': 2517,
#  'club': 1955,
#  'unsubscribe': 7584,
#  'service': 6385,
#  'reply': 6049,
#  'stop': 6880,
#  'msgs150p': 4898,
#  '18': 349,
#  'ha': 3442,
#  'must': 4941,
#  'walk': 7776,
#  'everywhere': 2810,
#  'cannot': 1722,
#  'tram': 7418,
#  'cousin': 2142,
#  'vic': 7690,
#  'market': 4609,
#  'hotel': 3680,
#  'replying': 6051,
#  'mix': 4799,
#  'see': 6335,
#  'mytonecomenjoy': 4953,
#  'html': 3707,
#  'terms': 7164,
#  'cost': 2119,
#  'gbp450week': 3236,
#  'mfl': 4733,
#  'omg': 5246,
#  'joanna': 4032,
#  'freaking': 3121,
#  'shes': 6437,
#  'looked': 4435,
#  'thru': 7274,
#  'friends': 3152,
#  'find': 2988,
#  'photos': 5511,
#  'asking': 1151,
#  'myspace': 4951,
#  'havent': 3508,
#  'even': 2794,
#  'logged': 4414,
#  'like': 4348,
#  'year': 8167,
#  'remind': 6022,
#  'hrs': 3706,
#  'im': 3798,
#  'lip': 4374,
#  'synced': 7053,
#  'shangela': 6420,
#  'howz': 3700,
#  'persons': 5485,
#  'story': 6894,
#  'important': 3811,
#  'customer': 2230,
#  'announcement': 1034,
#  'premier': 5711,
#  'sister': 6545,
#  'law': 4272,
#  'hope': 3660,
#  'month': 4855,
#  'saying': 6278,
#  'abiola': 815,
#  'kkhow': 4171,
#  'business': 1641,
#  'pure': 5831,
#  'hearted': 3528,
#  'person': 5479,
#  'wonderful': 8007,
#  'smile': 6616,
#  'makes': 4575,
#  'hisher': 3599,
#  'enemies': 2721,
#  'feel': 2942,
#  'guilty': 3430,
#  'enemy': 2722,
#  'catch': 1771,
#  'world': 8031,
#  'goodmorning': 3338,
#  'amp': 1010,
#  'smiley': 6619,
#  'sunday': 6988,
#  'aslamalaikkuminsha': 1153,
#  'allah': 975,
#  'tohar': 7341,
#  'beeen': 1344,
#  'muht': 4919,
#  'albi': 958,
#  'mufti': 4917,
#  'mahfuuzmeaning': 4564,
#  'dude': 2612,
#  'knw': 4192,
#  'also': 992,
#  'teluguthts': 7150,
#  'gudk': 3418,
#  'gud': 3417,
#  'nyt': 5178,
#  'mus': 4936,
#  'ask': 1147,
#  'wat': 7814,
#  'lunch': 4512,
#  'den': 2369,
#  'already': 987,
#  'lor': 4445,
#  'wan': 7790,
#  'da': 2243,
#  'ge': 3241,
#  'confirm': 2055,
#  'asap': 1140,
#  'allo': 980,
#  'braved': 1549,
#  'buses': 1639,
#  'taken': 7076,
#  'trains': 7417,
#  'triumphed': 7449,
#  'mean': 4658,
#  'ham': 3464,
#  'jolly': 4051,
#  'good': 3332,
#  'rest': 6082,
#  'list': 4378,
#  'buyers': 1650,
#  'em': 2700,
#  'olowoyey': 5244,
#  'uscedu': 7625,
#  'argentina': 1108,
#  'sad': 6218,
#  'secretary': 6327,
#  'everything': 2808,
#  'blessing': 1445,
#  'finished': 2998,
#  'missing': 4786,
#  'plenty': 5574,
#  'dont': 2536,
#  'tease': 7131,
#  'simply': 6527,
#  'grins': 3397,
#  'keep': 4116,
#  'posted': 5659,
#  'prey': 5734,
#  'loving': 4479,
#  'devouring': 2413,
#  'kiss': 4159,
#  'hi': 3583,
#  'hols': 3636,
#  'yes': 8177,
#  'bit': 1423,
#  'run': 6200,
#  'forgot': 3089,
#  'hairdressers': 3455,
#  'appointment': 1082,
#  'four': 3106,
#  'need': 5007,
#  'shower': 6486,
#  'beforehand': 1352,
#  'cause': 1776,
#  'prob': 5756,
#  'bus': 1637,
#  'come': 2003,
#  'soon': 6686,
#  'otherwise': 5313,
#  'tomorrow': 7357,
#  '09095350301': 245,
#  'send': 6362,
#  'girls': 3287,
#  'erotic': 2759,
#  'ecstacy': 2655,
#  '60pmin': 632,
#  'texts': 7186,
#  '08712460324': 103,
#  'nat': 4980,
#  'rate': 5901,
#  'enjoy': 2730,
#  'showers': 6488,
#  'possessiveness': 5650,
#  'poured': 5669,
#  'ur': 7608,
#  'loved': 4471,
#  'ones': 5253,
#  'bcoz': 1319,
#  'lies': 4334,
#  'golden': 3325,
#  'gift': 3276,
#  'truly': 7457,
#  'chance': 1811,
#  'win': 7945,
#  '250': 411,
#  'wkly': 7986,
#  'shopping': 6466,
#  'spree': 6786,
#  'shop': 6464,
#  '80878': 708,
#  'tscs': 7468,
#  'wwwtxt2shopcom': 8120,
#  'custcare': 2227,
#  '08715705022': 121,
#  '1x150pwk': 379,
#  'watching': 7819,
#  'tv': 7490,
#  'maths': 4633,
#  'one': 5251,
#  'day': 2293,
#  'chapter': 1819,
#  'finish': 2996,
#  'contract': 2085,
#  'mobile': 4817,
#  '11': 274,
#  'mnths': 4812,
#  'latest': 4262,
#  'motorola': 4875,
#  'etc': 2780,
#  'double': 2547,
#  'mins': 4766,
#  'text': 7177,
#  'orange': 5292,
#  'tariffs': 7096,
#  'callback': 1687,
#  'remove': 6028,
#  'records': 5970,
#  'doesnt': 2512,
#  'stalk': 6812,
#  'profiles': 5776,
#  'tension': 7160,
#  'ahwhat': 939,
#  'machiany': 4541,
#  'problem': 5758,
#  'doc': 2502,
#  'pls': 5577,
#  'want': 7795,
#  'nice': 5047,
#  'shirt': 6448,
#  'hubby': 3721,
#  'fiting': 3012,
#  'budget': 1615,
#  'ltgt': 4498,
#  'help': 3550,
#  'load': 4401,
#  'card': 1732,
#  'abi': 813,
#  'hwkeep': 3755,
#  'luv': 4516,
#  'mj': 4800,
#  'excellent': 2828,
#  'wish': 7966,
#  'together': 7340,
#  'right': 6121,
#  'movie': 4883,
#  'collect': 1989,
#  'car': 1731,
#  'oredi': 5299,
#  'seeing': 6337,
#  'missed': 4784,
#  'dear': 2315,
#  'spending': 6748,
#  'years': 8168,
#  'family': 2902,
#  'lets': 4320,
#  'plan': 5550,
#  'next': 5042,
#  'ready': 5927,
#  'spoiled': 6770,
#  'boo': 1488,
#  'hows': 3698,
#  'things': 7238,
#  'back': 1251,
#  'little': 4387,
#  'bored': 1500,
#  'weird': 7870,
#  'point': 5609,
#  'captain': 1729,
#  'vijaykanth': 7699,
#  'comedy': 2004,
#  'tvhe': 7491,
#  'drunken': 2603,
#  'information': 3855,
#  'o2': 5183,
#  'user': 7630,
#  'today': 7333,
#  'lucky': 4506,
#  'log': 4413,
#  'onto': 5264,
#  'httpwwwurawinnercom': 3717,
#  'fantastic': 2911,
#  'surprise': 7016,
#  'awaiting': 1221,
#  'link': 4367,
#  'picture': 5524,
#  'sent': 6373,
#  'use': 7626,
#  'httpalto18coukwavewaveaspo44345': 3708,
#  'guys': 3435,
#  'planning': 5556,
#  'coming': 2011,
#  'wont': 8010,
#  'disturb': 2488,
#  'avoiding': 1218,
#  'burden': 1629,
#  'well': 7877,
#  'general': 3248,
#  'price': 5735,
#  'oz': 5352,
#  'let': 4319,
#  'ifwhenhow': 3785,
#  'much': 4912,
#  'ding': 2455,
#  'ya': 8151,
#  'break': 1554,
#  'fassyole': 2916,
#  'blacko': 1431,
#  'londn': 4425,
#  'worse': 8044,
#  'uses': 7631,
#  'way': 7830,
#  'stops': 6886,
#  'better': 1386,
#  'complete': 2031,
#  'part': 5404,
#  'job': 4033,
#  'natuition': 4986,
#  'detroit': 2406,
#  'snow': 6645,
#  'lar': 4248,
#  'joking': 4050,
#  'wif': 7934,
#  'oni': 5254,
#  'initiate': 3865,
#  'understand': 7550,
#  'done': 2533,
#  'sorry': 6698,
#  'space': 6722,
#  'gives': 3292,
#  'remember': 6016,
#  'furniture': 3194,
#  'around': 1123,
#  'move': 4880,
#  'lock': 4410,
#  'locks': 4411,
#  'leave': 4291,
#  'key': 4129,
#  'jenne': 4013,
#  'ìï': 8254,
#  'got': 3352,
#  'lessons': 4318,
#  'sch': 6289,
#  'theory': 7222,
#  'argument': 1112,
#  'wins': 7959,
#  'situation': 6553,
#  'loses': 4451,
#  'argue': 1110,
#  'kick': 4139,
#  'always': 997,
#  'correct': 2111,
#  '09050003091': 165,
#  'c52': 1664,
#  'partys': 5412,
#  'place': 5546,
#  'charge': 1821,
#  'contribute': 2086,
#  'greatly': 3390,
#  'appreciated': 1085,
#  'yeah': 8166,
#  'room': 6162,
#  'surely': 7012,
#  'comei': 2005,
#  'touch': 7399,
#  'natalja': 4982,
#  '25f': 414,
#  'inviting': 3914,
#  'friend': 3151,
#  'yes440': 8180,
#  'no440': 5080,
#  'wwwsmsacunat27081980': 8113,
#  'frnd': 3158,
#  '62468': 637,
#  'idea': 3774,
#  'guess': 3423,
#  'work': 8023,
#  'hour': 3684,
#  'supposed': 7007,
#  'since': 6530,
#  'usual': 7640,
#  'nobody': 5085,
#  'interest': 3893,
#  'figuring': 2974,
#  'shit': 6450,
#  'last': 4255,
#  'second': 6323,
#  'polyphonic': 5623,
#  'ringtone': 6130,
#  'super': 6997,
#  '87131': 754,
#  'poly': 5617,
#  'tone': 7361,
#  'sn': 6635,
#  'pobox202': 5594,
#  'nr31': 5151,
#  '7zs': 693,
#  'subscription': 6953,
#  '450pw': 558,
#  'bangbabes': 1274,
#  'order': 5296,
#  'receive': 5954,
#  'msg': 4893,
#  'download': 2554,
#  'content': 2080,
#  'goto': 3355,
#  'wap': 7800,
#  'bangb': 1273,
#  'internetservice': 3900,
#  'menu': 4703,
#  'test': 7172,
#  'rd': 5916,
#  'fink': 3001,
#  'met': 4730,
#  'yet': 8188,
#  'please': 5569,
#  '2day': 434,
#  'wiv': 7980,
#  'area': 1104,
#  '09099726553': 251,
#  'promised': 5787,
#  'carlie': 1747,
#  'callså': 1704,
#  '1minmobsmore': 367,
#  'lkpobox177hp51fl': 4395,
#  'ni8': 5044,
#  'dearslp': 2325,
#  'welltake': 7880,
#  'careswt': 1745,
#  'dreamsmuah': 2574,
#  'ive': 3971,
#  'booked': 1491,
#  'sun': 6986,
#  'liao': 4325,
#  'set': 6389,
#  'heart': 3527,
#  'easily': 2642,
#  'forgets': 3086,
#  'happy': 3491,
#  'valentines': 7657,
#  'jos': 4057,
#  'wana': 7792,
#  'song': 6680,
#  'dedicated': 2341,
#  'dedicate': 2340,
#  'valuable': 7660,
#  'frnds': 3159,
#  'first': 3008,
#  'rply': 6178,
#  'jay': 4000,
#  'wants': 7799,
#  'sound': 6710,
#  'chosen': 1904,
#  '350': 500,
#  'award': 1223,
#  'number': 5159,
#  '09066364311': 229,
#  'selected': 6349,
#  'valued': 7662,
#  'west': 7893,
#  'coast': 1966,
#  'haiz': 3457,
#  'ìïll': 8255,
#  'forever': 3082,
#  'show': 6484,
#  'colours': 2000,
#  'euro': 2785,
#  '2004': 386,
#  '241': 404,
#  'offer': 5204,
#  'england': 2728,
#  'flag': 3019,
#  '3lions': 520,
#  'phone': 5504,
#  'click': 1939,
#  'following': 3062,
#  'info': 3852,
#  'tells': 7147,
#  '09066358152': 223,
#  '5000': 594,
#  'enter': 2738,
#  'personal': 5481,
#  'details': 2403,
#  'prompts': 5792,
#  'careful': 1739,
#  '1000': 256,
#  'cash': 1760,
#  '2000': 383,
#  'yr': 8228,
#  'representative': 6054,
#  '08714712412': 112,
#  '10am7pm': 267,
#  '10p': 270,
#  'yup': 8236,
#  'thanx': 7197,
#  'printing': 5744,
#  'handing': 3469,
#  'idk': 3780,
#  'sitting': 6552,
#  'parking': 5403,
#  'lot': 4455,
#  'bawling': 1306,
#  'eyes': 2873,
#  'failure': 2887,
#  'failing': 2885,
#  'horrible': 3671,
#  'gal': 3205,
#  'mc': 4652,
#  'awesome': 1226,
#  '4u': 588,
#  'couple': 2138,
#  'times': 7299,
#  'alls': 982,
#  'love': 4469,
#  'awake': 1222,
#  'could': 2130,
#  'carlos': 1749,
#  'anybody': 1048,
#  'else': 2698,
#  'chip': 1892,
#  'morning': 4865,
#  'shijutta': 6441,
#  'successful': 6958,
#  'thanks': 7194,
#  'lol': 4422,
#  'ill': 3795,
#  'post': 5655,
#  'l8r': 4211,
#  'class': 1925,
#  'youre': 8216,
#  'maybe': 4650,
#  'credit': 2172,
#  'gas': 3225,
#  'told': 7346,
#  'lord': 4446,
#  'ringsreturn': 6129,
#  'king': 4155,
#  'store': 6889,
#  'nowreply': 5145,
#  'lotr': 4457,
#  'june': 4076,
#  'soundtrack': 6713,
#  'cds': 1785,
#  'stdtxtrate': 6846,
#  'txts': 7508,
#  'frm': 3157,
#  'wats': 7827,
#  'matter': 4637,
#  'paper': 5383,
#  'morn': 4864,
#  'aft': 906,
#  'actually': 862,
#  'decided': 2332,
#  'hungry': 3736,
#  'left': 4297,
#  'film': 2981,
#  'machan': 4540,
#  'gym': 3439,
#  'wil': 7941,
#  'late': 4256,
#  'goodnight': 3340,
#  'online': 5257,
#  'yahoo': 8153,
#  'would': 8052,
#  'chat': 1832,
#  'someday': 6664,
#  'dog': 2514,
#  'wait': 7765,
#  'till': 7295,
#  'word': 8017,
#  'cell': 1793,
#  'small': 6604,
#  'kid': 4143,
#  'boost': 1496,
#  'secret': 6326,
#  'energy': 2723,
#  'goodmorningmy': 3339,
#  'grandfather': 3374,
#  'expiredso': 2855,
#  'short': 6472,
#  'cute': 2233,
#  'hm': 3612,
#  'headache': 3516,
#  'anyone': 1051,
#  'moneyas': 4845,
#  'youmoney': 8211,
#  'aint': 944,
#  'thinghow': 7237,
#  'sha': 6406,
#  'whatever': 7902,
#  'juliana': 4071,
#  'check': 1843,
#  'rooms': 6166,
#  'befor': 1351,
#  'activities': 860,
#  'months': 4858,
#  'entitled': 2746,
#  'update': 7591,
#  'colour': 1997,
#  'mobiles': 4818,
#  'camera': 1709,
#  'co': 1964,
#  '08002986030': 51,
#  'meeting': 4676,
#  'people': 5461,
#  'dearer': 2317,
#  'de': 2306,
#  'happiness': 3490,
#  'pain': 5365,
#  'miss': 4783,
#  'dem': 2367,
#  'webadres': 7845,
#  'geting': 3265,
#  'salary': 6230,
#  'slip': 6594,
#  'gonna': 3330,
#  'steam': 6850,
#  'salespee': 6234,
#  'drive': 2585,
#  'someplace': 6668,
#  'official': 5214,
#  'yer': 8176,
#  'tonights': 7368,
#  'game': 3212,
#  '84199': 734,
#  'optout': 5288,
#  'eng': 2724,
#  'box39822': 1526,
#  'w111wx': 7747,
#  '150': 311,
#  'yay': 8163,
#  'either': 2687,
#  'phones': 5508,
#  'linerental': 4362,
#  '449month': 554,
#  '750': 676,
#  'cross': 2186,
#  'ntwk': 5155,
#  '12': 284,
#  'bundle': 1626,
#  'deals': 2313,
#  'avble': 1211,
#  '08001950382': 49,
#  'call2optoutj': 1683,
#  'mf': 4732,
#  'itmail': 3956,
#  'panren': 5377,
#  'paru': 5413,
#  'mate': 4627,
#  'spoke': 6771,
#  'mag': 4555,
#  'deliver': 2363,
#  '24th': 409,
#  'sept': 6378,
#  'talk': 7083,
#  'yeshere': 8184,
#  'available': 1207,
#  'went': 7885,
#  'bed': 1339,
#  'cant': 1724,
#  'sleep': 6580,
#  'anything': 1056,
#  'long': 4429,
#  'defer': 2349,
#  'admission': 877,
#  'til': 7294,
#  'man': 4584,
#  'bday': 1324,
#  'didnt': 2431,
#  'parents': 5395,
#  'kids': 4145,
#  'colleagues': 1988,
#  'watchin': 7818,
#  'lido': 4332,
#  'germany': 3261,
#  'pence': 5455,
#  'per': 5463,
#  'fixed': 3016,
#  'via': 7686,
#  'access': 833,
#  '0844': 58,
#  '861': 745,
#  '85': 736,
#  'prepayment': 5716,
#  'direct': 2461,
#  'wwwtelediscountcouk': 8117,
#  'sure': 7011,
#  'whenever': 7908,
#  'fuck': 3172,
#  'gt': 3413,
#  'costa': 2120,
#  'del': 2356,
#  'sol': 6657,
#  'holiday': 3633,
#  'await': 1220,
#  'collection': 1992,
#  '09050090044': 167,
#  'toclaim': 7332,
#  'sae': 6219,
#  'tc': 7114,
#  'pobox334': 5595,
#  'stockport': 6873,
#  'sk38xh': 6561,
#  'costå': 2125,
#  '150pm': 320,
#  'max10mins': 4644,
#  'waiting': 7769,
#  'tmobile': 7324,
#  'may': 4648,
#  'upgrade': 7593,
#  'pay': 5436,
#  'sim': 6523,
#  'loyalty': 4487,
#  '0845': 61,
#  '021': 13,
#  '3680offer': 506,
#  'ends': 2720,
#  '28thfebtcs': 426,
#  'apply': 1078,
#  'cmon': 1961,
#  'babe': 1242,
#  'make': 4574,
#  'horny': 3669,
#  'turn': 7485,
#  'fantasy': 2912,
#  'hot': 3679,
#  'sticky': 6866,
#  'replies': 6048,
#  'cancel': 1717,
#  'tired': 7306,
#  'special': 6735,
#  'tirupur': 7310,
#  'evo': 2815,
#  'flash': 3023,
#  'jealous': 4007,
#  'jot': 4058,
#  'sleeping': 6582,
#  'spys': 6792,
#  'checking': 1847,
#  'mails': 4569,
#  'sec': 6322,
#  'beautiful': 1331,
#  'truth': 7461,
#  'gravity': 3381,
#  'read': 5923,
#  'carefully': 1740,
#  'feels': 2945,
#  'light': 4344,
#  'someone': 6665,
#  'heavy': 3536,
#  'leaves': 4292,
#  'drop': 2592,
#  '10k': 269,
#  '5k': 614,
#  '500': 593,
#  '100': 255,
#  'travel': 7430,
#  'voucher': 7737,
#  '09064011000': 207,
#  'ntt': 5154,
#  'po': 5587,
#  'box': 1517,
#  'cr01327bt': 2151,
#  'fixedline': 3017,
#  '150ppm': 329,
#  'vary': 7669,
#  'real': 5929,
#  'thing': 7236,
#  'princess': 5741,
#  'wet': 7897,
#  'activate': 858,
#  'messages': 4721,
#  'conditions': 2050,
#  'visit': 7715,
#  'www07781482378com': 8086,
#  'greatest': 3389,
#  'courage': 2139,
#  'earth': 2639,
#  'bear': 1327,
#  'defeat': 2348,
#  'without': 7976,
#  'losing': 4452,
#  'heartgn': 3529,
#  'mumhas': 4924,
#  'beendropping': 1346,
#  'red': 5976,
#  'wine': 7952,
#  'theplace': 7223,
#  'adress': 883,
#  'watch': 7815,
#  'resizing': 6069,
#  'future': 3196,
#  'planned': 5555,
#  'result': 6092,
#  'best': 1380,
#  'present': 5722,
#  'taking': 7080,
#  'survey': 7020,
#  'yesterday': 8187,
#  'however': 3696,
#  '80160': 701,
#  'wwwtxt43com': 8121,
#  '150p': 317,
#  'chikku': 1870,
#  'thts': 7278,
#  'nt': 5152,
#  'looking': 4437,
#  'buy': 1648,
#  'gone': 3328,
#  '4the': 585,
#  'driving': 2588,
#  'hii': 3591,
#  'money': 4844,
#  'auctionpunj': 1189,
#  'tiwary': 7316,
#  'er': 2755,
#  '1526': 341,
#  'tell': 7144,
#  'pubcafe': 5817,
#  'sit': 6547,
#  'wen': 7883,
#  'hanks': 3479,
#  'lotsly': 4459,
#  'hello': 3544,
#  'lover': 4475,
#  'goes': 3317,
#  'think': 7239,
#  'wake': 7772,
#  'slave': 6579,
#  'teasing': 7132,
#  'across': 852,
#  'sea': 6317,
#  'bad': 1253,
#  'problems': 5763,
#  'whos': 7926,
#  'drugdealer': 2598,
#  'local': 4406,
#  'dates': 2284,
#  'lots': 4458,
#  'registered': 5996,
#  'date': 2282,
#  'start': 6825,
#  'wwwflirtpartyus': 8096,
#  'replys150': 6052,
#  'dearshall': 2324,
#  'mail': 4565,
#  'tonitebusy': 7370,
#  'streetshall': 6901,
#  'tonitethings': 7371,
#  'okvarunnathu': 5236,
#  'edukkukayee': 2664,
#  'raksha': 5892,
#  'ollubut': 5242,
#  'sense': 6369,
#  'mon': 4841,
#  'thurs': 7280,
#  'sat': 6260,
#  'leh': 4302,
#  'plz': 5584,
#  'sir': 6540,
#  'daily': 2256,
#  'ûò': 8261,
#  'favour': 2933,
#  'coughing': 2129,
#  'nothing': 5127,
#  'smsing': 6631,
#  'xy': 8149,
#  'neva': 5030,
#  'sort': 6701,
#  'bring': 1575,
#  'along': 985,
#  'btw': 1609,
#  'regarding': 5993,
#  '4th': 584,
#  'commit': 2017,
#  'random': 5895,
#  'ard': 1102,
#  '10': 254,
#  'smth': 6634,
#  '09066358361': 224,
#  'y87': 8150,
#  'valid': 7658,
#  '12hrs': 296,
#  'staffsciencenusedusgphyhcmkteachingpc1323': 6808,
#  'happen': 3482,
#  'alright': 989,
#  'fuuuuck': 3197,
#  'sleepin': 6581,
#  'sup': 6996,
#  'vote': 7735,
#  'caring': 1746,
#  'losers': 4450,
#  'project': 5781,
#  ...}

# %%
# How are these vectors stored?
X_test_vect[0]
# Out:
# <1x8263 sparse matrix of type '<class 'numpy.float64'>'
# 	with 9 stored elements in Compressed Sparse Row format>

# %%
# Can we convert the vectors to arrays?
X_test_vect[0].toarray()
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %% [markdown]
# ### Fit RandomForestClassifier On Top Of Vectors

# %%
# Fit a basic Random Forest model on these vectors
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf_model = rf.fit(X_train_vect, y_train.values.ravel())

# %%
# Use the trained model to make predictions on the test data
y_pred = rf_model.predict(X_test_vect)

# %%
# Evaluate the predictions of the model on the holdout test set
from sklearn.metrics import precision_score, recall_score

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
print('Precision: {} / Recall: {} / Accuracy: {}'.format(
    round(precision, 3), round(recall, 3), round((y_pred==y_test['label']).sum()/len(y_pred), 3)))
# Out:
# Precision: 1.0 / Recall: 0.795 / Accuracy: 0.97
